# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
# reading csv files
data =  pd.read_csv('D:/HomeWork/iris.data', sep=",",header = None)
setosa = data[data[4] == 'Iris-setosa']
virginica = data[data[4] == 'Iris-virginica']
versicolor = data[data[4] == 'Iris-versicolor']
print(data)
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#Feature 1 and 2
F1_setosa = setosa[0]
F2_setosa = setosa[1]

F1_virginica = virginica[0]
F2_virginica = virginica[1]

F1_versicolor = versicolor[0]
F2_versicolor = versicolor[1]


plt.plot(F1_setosa,F2_setosa , linestyle='', marker='o', color="red", label='setosa')
plt.plot(F1_virginica,F2_virginica , linestyle='', marker='o', color="blue", label='virginica')
plt.plot(F1_versicolor,F2_versicolor , linestyle='', marker='o', color="black", label='versicolor')
plt.title('Feature 1 and 2')
plt.xlabel('F1')
plt.ylabel('F2')
plt.legend()

plt.show()

# %%
#Feature 1 and 3
F1_setosa = setosa[0]
F3_setosa = setosa[2]

F1_virginica = virginica[0]
F3_virginica = virginica[2]

F1_versicolor = versicolor[0]
F3_versicolor = versicolor[2]


plt.plot(F1_setosa,F3_setosa , linestyle='', marker='o', color="red", label='setosa')
plt.plot(F1_virginica,F3_virginica , linestyle='', marker='o', color="blue", label='virginica')
plt.plot(F1_versicolor,F3_versicolor , linestyle='', marker='o', color="black", label='versicolor')
plt.title('Feature 1 and 3')
plt.xlabel('F1')
plt.ylabel('F3')
plt.legend()

plt.show()

# %%
#Feature 2 and 4
F2_setosa = setosa[1]
F4_setosa = setosa[3]

F2_virginica = virginica[1]
F4_virginica = virginica[3]

F2_versicolor = versicolor[1]
F4_versicolor = versicolor[3]


plt.plot(F2_setosa,F4_setosa , linestyle='', marker='o', color="red", label='setosa')
plt.plot(F2_virginica,F4_virginica , linestyle='', marker='o', color="blue", label='virginica')
plt.plot(F2_versicolor,F4_versicolor , linestyle='', marker='o', color="black", label='versicolor')
plt.title('Feature 2 and 4')
plt.xlabel('F2')
plt.ylabel('F4')
plt.legend()

plt.show()
