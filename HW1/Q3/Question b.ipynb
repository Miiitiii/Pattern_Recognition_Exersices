# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
# reading csv files
data =  pd.read_csv('D:/HomeWork/iris.data', sep=",",header = None)

T1 = np.array([1.2 , -0.3])
T2 = np.array([-1.8 , 0.6])
T3 = np.array([1.4 , 0.5])
T4 = np.array([-0.5 , -1])

# %%
#Feature 1 and 2 with T1
setosa = data[data[4] == 'Iris-setosa']
virginica = data[data[4] == 'Iris-virginica']
versicolor = data[data[4] == 'Iris-versicolor']

setosa = setosa[setosa.columns[0:2]]
virginica = virginica[virginica.columns[0:2]]
versicolor = versicolor[versicolor.columns[0:2]]

setosa =np.matmul(setosa , T1)
virginica =np.matmul(virginica , T1)
versicolor =np.matmul(versicolor , T1)

plt.hist(setosa , color = 'red', label='setosa', edgecolor='None', alpha = 0.7)
plt.hist(virginica , color = 'blue', label='virginica', edgecolor='None', alpha = 0.7)
plt.hist(versicolor , color = 'black', label='versicolor', edgecolor='None', alpha = 0.7)
plt.title('Feature 1 and 2 with T1')
plt.ylabel('Probability')
plt.xlabel('Data');
plt.legend()

plt.show()

# %%
#Feature 1 and 2 with T2
setosa = data[data[4] == 'Iris-setosa']
virginica = data[data[4] == 'Iris-virginica']
versicolor = data[data[4] == 'Iris-versicolor']

setosa = setosa[setosa.columns[0:2]]
virginica = virginica[virginica.columns[0:2]]
versicolor = versicolor[versicolor.columns[0:2]]

setosa =np.matmul(setosa , T2)
virginica =np.matmul(virginica , T2)
versicolor =np.matmul(versicolor , T2)

plt.hist(setosa , color = 'red', label='setosa', edgecolor='None', alpha = 0.7)
plt.hist(virginica , color = 'blue', label='virginica', edgecolor='None', alpha = 0.7)
plt.hist(versicolor , color = 'black', label='versicolor', edgecolor='None', alpha = 0.7)
plt.title('Feature 1 and 2 with T2')

plt.ylabel('Probability')
plt.xlabel('Data');
plt.legend()

plt.show()

# %%
#Feature 1 and 2 with T3
setosa = data[data[4] == 'Iris-setosa']
virginica = data[data[4] == 'Iris-virginica']
versicolor = data[data[4] == 'Iris-versicolor']

setosa = setosa[setosa.columns[0:2]]
virginica = virginica[virginica.columns[0:2]]
versicolor = versicolor[versicolor.columns[0:2]]

setosa =np.matmul(setosa , T3)
virginica =np.matmul(virginica , T3)
versicolor =np.matmul(versicolor , T3)

plt.hist(setosa , color = 'red', label='setosa', edgecolor='None', alpha = 0.7)
plt.hist(virginica , color = 'blue', label='virginica', edgecolor='None', alpha = 0.7)
plt.hist(versicolor , color = 'black', label='versicolor', edgecolor='None', alpha = 0.7)
plt.title('Feature 1 and 2 with T3')

plt.ylabel('Probability')
plt.xlabel('Data');
plt.legend()

plt.show()

# %%
#Feature 1 and 2 with T4
setosa = data[data[4] == 'Iris-setosa']
virginica = data[data[4] == 'Iris-virginica']
versicolor = data[data[4] == 'Iris-versicolor']

setosa = setosa[setosa.columns[0:2]]
virginica = virginica[virginica.columns[0:2]]
versicolor = versicolor[versicolor.columns[0:2]]

setosa =np.matmul(setosa , T4)
virginica =np.matmul(virginica , T4)
versicolor =np.matmul(versicolor , T4)

plt.hist(setosa , color = 'red', label='setosa', edgecolor='None', alpha = 0.7)
plt.hist(virginica , color = 'blue', label='virginica', edgecolor='None', alpha = 0.7)
plt.hist(versicolor , color = 'black', label='versicolor', edgecolor='None', alpha = 0.7)
plt.title('Feature 1 and 2 with T4')

plt.ylabel('Probability')
plt.xlabel('Data');
plt.legend()

plt.show()

# %%
#Feature 1 and 3 with T1
setosa = data[data[4] == 'Iris-setosa']
virginica = data[data[4] == 'Iris-virginica']
versicolor = data[data[4] == 'Iris-versicolor']

setosa = setosa.loc[: , [0,2]]
virginica = virginica.loc[:, [0,2]]
versicolor = versicolor.loc[:, [0,2]]

setosa =np.matmul(setosa , T1)
virginica =np.matmul(virginica , T1)
versicolor =np.matmul(versicolor , T1)

plt.hist(setosa , color = 'red', label='setosa', edgecolor='None', alpha = 0.7)
plt.hist(virginica , color = 'blue', label='virginica', edgecolor='None', alpha = 0.7)
plt.hist(versicolor , color = 'black', label='versicolor', edgecolor='None', alpha = 0.7)
plt.title('Feature 1 and 3 with T1')

plt.ylabel('Probability')
plt.xlabel('Data');
plt.legend()

plt.show()

# %%
#Feature 1 and 3 with T2
setosa = data[data[4] == 'Iris-setosa']
virginica = data[data[4] == 'Iris-virginica']
versicolor = data[data[4] == 'Iris-versicolor']

setosa = setosa.loc[: , [0,2]]
virginica = virginica.loc[:, [0,2]]
versicolor = versicolor.loc[:, [0,2]]

setosa =np.matmul(setosa , T2)
virginica =np.matmul(virginica , T2)
versicolor =np.matmul(versicolor , T2)

plt.hist(setosa , color = 'red', label='setosa', edgecolor='None', alpha = 0.7)
plt.hist(virginica , color = 'blue', label='virginica', edgecolor='None', alpha = 0.7)
plt.hist(versicolor , color = 'black', label='versicolor', edgecolor='None', alpha = 0.7)
plt.title('Feature 1 and 3 with T2')

plt.ylabel('Probability')
plt.xlabel('Data');
plt.legend()

plt.show()

# %%
#Feature 1 and 3 with T3
setosa = data[data[4] == 'Iris-setosa']
virginica = data[data[4] == 'Iris-virginica']
versicolor = data[data[4] == 'Iris-versicolor']

setosa = setosa.loc[: , [0,2]]
virginica = virginica.loc[:, [0,2]]
versicolor = versicolor.loc[:, [0,2]]

setosa =np.matmul(setosa , T3)
virginica =np.matmul(virginica , T3)
versicolor =np.matmul(versicolor , T3)

plt.hist(setosa , color = 'red', label='setosa', edgecolor='None', alpha = 0.7)
plt.hist(virginica , color = 'blue', label='virginica', edgecolor='None', alpha = 0.7)
plt.hist(versicolor , color = 'black', label='versicolor', edgecolor='None', alpha = 0.7)
plt.title('Feature 1 and 3 with T3')

plt.ylabel('Probability')
plt.xlabel('Data');
plt.legend()

plt.show()

# %%
#Feature 1 and 3 with T4
setosa = data[data[4] == 'Iris-setosa']
virginica = data[data[4] == 'Iris-virginica']
versicolor = data[data[4] == 'Iris-versicolor']

setosa = setosa.loc[: , [0,2]]
virginica = virginica.loc[:, [0,2]]
versicolor = versicolor.loc[:, [0,2]]

setosa =np.matmul(setosa , T4)
virginica =np.matmul(virginica , T4)
versicolor =np.matmul(versicolor , T4)

plt.hist(setosa , color = 'red', label='setosa', edgecolor='None', alpha = 0.7)
plt.hist(virginica , color = 'blue', label='virginica', edgecolor='None', alpha = 0.7)
plt.hist(versicolor , color = 'black', label='versicolor', edgecolor='None', alpha = 0.7)
plt.title('Feature 1 and 3 with T4')

plt.ylabel('Probability')
plt.xlabel('Data');
plt.legend()

plt.show()

# %%
#Feature 2 and 4 with T1
setosa = data[data[4] == 'Iris-setosa']
virginica = data[data[4] == 'Iris-virginica']
versicolor = data[data[4] == 'Iris-versicolor']

setosa = setosa.loc[: , [1,3]]
virginica = virginica.loc[:, [1,3]]
versicolor = versicolor.loc[:, [1,3]]

setosa =np.matmul(setosa , T1)
virginica =np.matmul(virginica , T1)
versicolor =np.matmul(versicolor , T1)

plt.hist(setosa , color = 'red', label='setosa', edgecolor='None', alpha = 0.7)
plt.hist(virginica , color = 'blue', label='virginica', edgecolor='None', alpha = 0.7)
plt.hist(versicolor , color = 'black', label='versicolor', edgecolor='None', alpha = 0.7)
plt.title('Feature 2 and 4 with T1')

plt.ylabel('Probability')
plt.xlabel('Data');
plt.legend()

plt.show()

# %%
#Feature 2 and 4 with T2
setosa = data[data[4] == 'Iris-setosa']
virginica = data[data[4] == 'Iris-virginica']
versicolor = data[data[4] == 'Iris-versicolor']

setosa = setosa.loc[: , [1,3]]
virginica = virginica.loc[:, [1,3]]
versicolor = versicolor.loc[:, [1,3]]

setosa =np.matmul(setosa , T2)
virginica =np.matmul(virginica , T2)
versicolor =np.matmul(versicolor , T2)

plt.hist(setosa , color = 'red', label='setosa', edgecolor='None', alpha = 0.7)
plt.hist(virginica , color = 'blue', label='virginica', edgecolor='None', alpha = 0.7)
plt.hist(versicolor , color = 'black', label='versicolor', edgecolor='None', alpha = 0.7)
plt.title('Feature 2 and 4 with T2')

plt.ylabel('Probability')
plt.xlabel('Data');
plt.legend()

plt.show()

# %%
#Feature 2 and 4 with T3
setosa = data[data[4] == 'Iris-setosa']
virginica = data[data[4] == 'Iris-virginica']
versicolor = data[data[4] == 'Iris-versicolor']

setosa = setosa.loc[: , [1,3]]
virginica = virginica.loc[:, [1,3]]
versicolor = versicolor.loc[:, [1,3]]

setosa =np.matmul(setosa , T3)
virginica =np.matmul(virginica , T3)
versicolor =np.matmul(versicolor , T3)

plt.hist(setosa , color = 'red', label='setosa', edgecolor='None', alpha = 0.7)
plt.hist(virginica , color = 'blue', label='virginica', edgecolor='None', alpha = 0.7)
plt.hist(versicolor , color = 'black', label='versicolor', edgecolor='None', alpha = 0.7)
plt.title('Feature 2 and 4 with T3')

plt.ylabel('Probability')
plt.xlabel('Data');
plt.legend()

plt.show()

# %%
#Feature 2 and 4 with T4
setosa = data[data[4] == 'Iris-setosa']
virginica = data[data[4] == 'Iris-virginica']
versicolor = data[data[4] == 'Iris-versicolor']

setosa = setosa.loc[: , [1,3]]
virginica = virginica.loc[:, [1,3]]
versicolor = versicolor.loc[:, [1,3]]

setosa =np.matmul(setosa , T4)
virginica =np.matmul(virginica , T4)
versicolor =np.matmul(versicolor , T4)

plt.hist(setosa , color = 'red', label='setosa', edgecolor='None', alpha = 0.7)
plt.hist(virginica , color = 'blue', label='virginica', edgecolor='None', alpha = 0.7)
plt.hist(versicolor , color = 'black', label='versicolor', edgecolor='None', alpha = 0.7)
plt.title('Feature 2 and 4 with T4')

plt.ylabel('Probability')
plt.xlabel('Data');
plt.legend()

plt.show()
